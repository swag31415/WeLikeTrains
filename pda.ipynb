# %% [markdown]
# # Load Libraries and Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
data = {f[:-4]:pd.read_csv(f) for f in os.listdir() if f.endswith('.csv')}

# %% [markdown]
# # Looking at the Data

# %%
data['train']
# Out:
#                   row_id  cfips          county    state first_day_of_month  \
# 0        1001_2019-08-01   1001  Autauga County  Alabama         2019-08-01
# 1        1001_2019-09-01   1001  Autauga County  Alabama         2019-09-01
# 2        1001_2019-10-01   1001  Autauga County  Alabama         2019-10-01
# 3        1001_2019-11-01   1001  Autauga County  Alabama         2019-11-01
# 4        1001_2019-12-01   1001  Autauga County  Alabama         2019-12-01
# ...                  ...    ...             ...      ...                ...
# 122260  56045_2022-06-01  56045   Weston County  Wyoming         2022-06-01
# 122261  56045_2022-07-01  56045   Weston County  Wyoming         2022-07-01
# 122262  56045_2022-08-01  56045   Weston County  Wyoming         2022-08-01
# 122263  56045_2022-09-01  56045   Weston County  Wyoming         2022-09-01
# 122264  56045_2022-10-01  56045   Weston County  Wyoming         2022-10-01
#
#         microbusiness_density  active
# 0                    3.007682    1249
# 1                    2.884870    1198
# 2                    3.055843    1269
# 3                    2.993233    1243
# 4                    2.993233    1243
# ...                       ...     ...
# 122260               1.803249     101
# 122261               1.803249     101
# 122262               1.785395     100
# 122263               1.785395     100
# 122264               1.785395     100
#
# [122265 rows x 7 columns]

# %%
data['census_starter']
# Out:
#       pct_bb_2017  pct_bb_2018  pct_bb_2019  pct_bb_2020  pct_bb_2021  cfips  \
# 0            76.6         78.9         80.6         82.7         85.5   1001
# 1            74.5         78.1         81.8         85.1         87.9   1003
# 2            57.2         60.4         60.5         64.6         64.6   1005
# 3            62.0         66.1         69.2         76.1         74.6   1007
# 4            65.8         68.5         73.0         79.6         81.0   1009
# ...           ...          ...          ...          ...          ...    ...
# 3137         82.2         82.4         84.0         86.7         88.4  56037
# 3138         83.5         85.9         87.1         89.1         90.5  56039
# 3139         83.8         88.2         89.5         91.4         90.6  56041
# 3140         76.4         78.3         78.2         82.8         85.4  56043
# 3141         71.1         73.3         76.8         79.7         81.3  56045
#
#       pct_college_2017  pct_college_2018  pct_college_2019  pct_college_2020  \
# 0                 14.5              15.9              16.1              16.7
# 1                 20.4              20.7              21.0              20.2
# 2                  7.6               7.8               7.6               7.3
# 3                  8.1               7.6               6.5               7.4
# 4                  8.7               8.1               8.6               8.9
# ...                ...               ...               ...               ...
# 3137              15.3              15.2              14.8              13.7
# 3138              37.7              37.8              38.9              37.2
# 3139              11.9              10.5              11.1              12.6
# 3140              15.4              15.0              15.4              15.0
# 3141              14.1              13.5              13.4              12.7
#
#       ...  pct_it_workers_2017  pct_it_workers_2018  pct_it_workers_2019  \
# 0     ...                  1.3                  1.1                  0.7
# 1     ...                  1.4                  1.3                  1.4
# 2     ...                  0.5                  0.3                  0.8
# 3     ...                  1.2                  1.4                  1.6
# 4     ...                  1.3                  1.4                  0.9
# ...   ...                  ...                  ...                  ...
# 3137  ...                  0.6                  0.6                  1.0
# 3138  ...                  0.7                  1.2                  1.4
# 3139  ...                  1.2                  1.2                  1.4
# 3140  ...                  1.3                  1.0                  0.9
# 3141  ...                  0.6                  0.6                  0.0
#
#       pct_it_workers_2020  pct_it_workers_2021  median_hh_inc_2017  \
# 0                     0.6                  1.1               55317
# 1                     1.0                  1.3               52562
# 2                     1.1                  0.8               33368
# 3                     1.7                  2.1               43404
# 4                     1.1                  0.9               47412
# ...                   ...                  ...                 ...
# 3137                  0.9                  1.0               71083
# 3138                  1.5                  2.0               80049
# 3139                  1.7                  0.9               54672
# 3140                  0.9                  1.1               51362
# 3141                  0.0                  0.0               59605
#
#       median_hh_inc_2018  median_hh_inc_2019  median_hh_inc_2020  \
# 0                58786.0               58731             57982.0
# 1                55962.0               58320             61756.0
# 2                34186.0               32525             34990.0
# 3                45340.0               47542             51721.0
# 4                48695.0               49358             48922.0
# ...                  ...                 ...                 ...
# 3137             73008.0               74843             73384.0
# 3138             83831.0               84678             87053.0
# 3139             58235.0               63403             72458.0
# 3140             53426.0               54158             57306.0
# 3141             52867.0               57031             53333.0
#
#       median_hh_inc_2021
# 0                62660.0
# 1                64346.0
# 2                36422.0
# 3                54277.0
# 4                52830.0
# ...                  ...
# 3137             76668.0
# 3138             94498.0
# 3139             75106.0
# 3140             62271.0
# 3141             65566.0
#
# [3142 rows x 26 columns]

# %%
data['test']
# Out:
#                  row_id  cfips first_day_of_month
# 0       1001_2022-11-01   1001         2022-11-01
# 1       1003_2022-11-01   1003         2022-11-01
# 2       1005_2022-11-01   1005         2022-11-01
# 3       1007_2022-11-01   1007         2022-11-01
# 4       1009_2022-11-01   1009         2022-11-01
# ...                 ...    ...                ...
# 25075  56037_2023-06-01  56037         2023-06-01
# 25076  56039_2023-06-01  56039         2023-06-01
# 25077  56041_2023-06-01  56041         2023-06-01
# 25078  56043_2023-06-01  56043         2023-06-01
# 25079  56045_2023-06-01  56045         2023-06-01
#
# [25080 rows x 3 columns]

# %%
data['sample_submission']
# Out:
#                  row_id  microbusiness_density
# 0       1001_2022-11-01               3.817671
# 1       1003_2022-11-01               3.817671
# 2       1005_2022-11-01               3.817671
# 3       1007_2022-11-01               3.817671
# 4       1009_2022-11-01               3.817671
# ...                 ...                    ...
# 25075  56037_2023-06-01               3.817671
# 25076  56039_2023-06-01               3.817671
# 25077  56041_2023-06-01               3.817671
# 25078  56043_2023-06-01               3.817671
# 25079  56045_2023-06-01               3.817671
#
# [25080 rows x 2 columns]

# %% [markdown]
# # Preprocessing

# %%
import sklearn.model_selection as skms

# %%
# Whole data processing
Xy = data['train'][['cfips', 'first_day_of_month', 'microbusiness_density']].copy()
Xy[['year', 'month', 'day']] = Xy['first_day_of_month'].str.split('-', expand=True)
Xy = Xy[['cfips', 'year', 'month', 'day', 'microbusiness_density']]
Xy = Xy.merge(data['census_starter'], on='cfips')
Xy = Xy[Xy['microbusiness_density'].notna()]

# %%
from sklearn.ensemble import IsolationForest
from sklearn.preprocessing import StandardScaler

# %%
# Split into Train / Test
Xy_train, Xy_test = skms.train_test_split(Xy, test_size=0.2)

# Train Processing
Xy_train.dropna(inplace=True)
# Xy_train = Xy_train[IsolationForest().fit_predict(Xy_train) == 1]

# Test Processing
Xy_test.fillna(-1, inplace=True)

# Split into X and y
y_train = Xy_train.pop('microbusiness_density')
y_test = Xy_test.pop('microbusiness_density')
X_train, X_test = Xy_train, Xy_test

# Scaling
sc = StandardScaler().fit(X_train)
X_train_scaled = sc.transform(X_train)
X_test_scaled = sc.transform(X_test)

# %%
X_train
# Out:
#         cfips  year month day  pct_bb_2017  pct_bb_2018  pct_bb_2019  \
# 110057  51011  2022    10  01         59.3         65.5         69.4
# 53632   27127  2020    03  01         66.9         69.6         72.0
# 111246  51075  2021    02  01         78.8         80.9         83.2
# 112580  51147  2021    10  01         62.2         66.0         66.7
# 20374   13279  2020    12  01         63.2         66.7         71.2
# ...       ...   ...   ...  ..          ...          ...          ...
# 114152  51678  2022    10  01         65.8         70.0         71.9
# 20130   13267  2020    02  01         65.2         69.5         72.8
# 90061   44003  2020    06  01         83.4         85.1         86.5
# 113648  51540  2019    10  01         78.2         81.1         84.3
# 26286   17163  2019    08  01         69.8         72.6         76.8
#
#         pct_bb_2020  pct_bb_2021  pct_college_2017  ...  pct_it_workers_2017  \
# 110057         74.1         76.8              11.7  ...                  1.4
# 53632          75.7         78.9              14.3  ...                  0.8
# 111246         85.8         88.0              24.6  ...                  1.9
# 112580         70.0         73.8              12.0  ...                  0.2
# 20374          76.7         76.6               9.8  ...                  0.9
# ...             ...          ...               ...  ...                  ...
# 114152         80.8         84.1              20.8  ...                  2.6
# 20130          77.8         77.0               7.4  ...                  0.5
# 90061          88.6         89.3              20.4  ...                  2.1
# 113648         85.7         87.8              24.8  ...                  2.3
# 26286          80.2         83.9              15.8  ...                  1.7
#
#         pct_it_workers_2018  pct_it_workers_2019  pct_it_workers_2020  \
# 110057                  1.4                  1.3                  0.3
# 53632                   0.8                  0.8                  1.0
# 111246                  2.5                  2.6                  2.1
# 112580                  0.3                  0.8                  0.7
# 20374                   0.7                  0.5                  0.9
# ...                     ...                  ...                  ...
# 114152                  2.1                  0.0                  0.0
# 20130                   0.4                  0.9                  0.8
# 90061                   1.7                  1.7                  1.9
# 113648                  2.7                  2.9                  3.7
# 26286                   1.6                  1.6                  1.7
#
#         pct_it_workers_2021  median_hh_inc_2017  median_hh_inc_2018  \
# 110057                  0.2               54875             56176.0
# 53632                   0.7               51871             53230.0
# 111246                  2.2               86652             89741.0
# 112580                  0.3               44147             46189.0
# 20374                   1.4               35750             36575.0
# ...                     ...                 ...                 ...
# 114152                  0.0               37309             36466.0
# 20130                   1.4               36355             38034.0
# 90061                   2.1               69047             70223.0
# 113648                  3.1               54739             58933.0
# 26286                   1.7               51103             53681.0
#
#         median_hh_inc_2019  median_hh_inc_2020  median_hh_inc_2021
# 110057               58696             55457.0             55268.0
# 53632                55404             57243.0             59638.0
# 111246               93994             97146.0            100517.0
# 112580               47202             44253.0             49019.0
# 20374                40175             41244.0             42975.0
# ...                    ...                 ...                 ...
# 114152               42632             50714.0             66114.0
# 20130                40730             44053.0             49977.0
# 90061                73521             75857.0             79880.0
# 113648               59471             59598.0             63470.0
# 26286                55179             57473.0             63017.0
#
# [97722 rows x 29 columns]

# %%
y_train
# Out:
# 110057     2.298297
# 53632      1.992582
# 111246     5.264557
# 112580     2.467593
# 20374      2.127874
#             ...
# 114152     8.771135
# 20130      1.322462
# 90061      6.164172
# 113648    13.267387
# 26286      4.827401
# Name: microbusiness_density, Length: 97722, dtype: float64

# %% [markdown]
# # Testing

# %%
def smape(a, f):
  return 1/len(a) * np.sum(2 * np.abs(f-a) / (np.abs(a) + np.abs(f))*100)

# %%
smape(np.random.random(1000), np.random.random(1000))
# Out:
# 76.21125176974918

# %%
k = np.random.random(10)
smape(k, k)
# Out:
# 0.0

# %% [markdown]
# # A dummy solution

# %%
# Zeros
smape(y_test, np.zeros_like(y_test))
# Out:
# 199.96728417781048

# %%
# Mean
smape(y_test, np.ones_like(y_test)*np.mean(y_train))
# Out:
# 62.36007971349328

# %% [markdown]
# # Hella basic models

# %%
from sklearn.linear_model import LinearRegression

# %%
m = LinearRegression().fit(X_train, y_train)
smape(y_test, m.predict(X_test))
# Out:
# 45.709769272055745

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
m = DecisionTreeRegressor().fit(X_train, y_train)
smape(y_test, m.predict(X_test))
# Out:
# 2.4340775696236956

# %%
m.predict(X_test)
# Out:
# array([4.3657722, 1.7011254, 2.6539462, ..., 4.5993128, 1.8455359,
#        1.0651373])

# %%
X_test
# Out:
#         cfips  year month day  pct_bb_2017  pct_bb_2018  pct_bb_2019  \
# 31685   19051  2021    01  01         61.9         62.8         64.5
# 23384   17013  2021    07  01         63.1         66.8         70.1
# 48732   26041  2021    05  01         72.1         73.7         76.2
# 145      1007  2021    12  01         62.0         66.1         69.2
# 14207   12093  2020    07  01         58.1         59.6         61.5
# ...       ...   ...   ...  ..          ...          ...          ...
# 117307  54045  2022    06  01         72.9         76.6         79.6
# 52933   27091  2020    06  01         74.8         76.8         78.9
# 91842   45083  2022    08  01         74.1         76.4         79.1
# 23524   17021  2020    03  01         72.6         76.5         77.3
# 37757   20165  2020    01  01         68.6         72.1         79.2
#
#         pct_bb_2020  pct_bb_2021  pct_college_2017  ...  pct_it_workers_2017  \
# 31685          64.9         66.7              11.9  ...                  2.5
# 23384          73.4         77.2               7.9  ...                  0.0
# 48732          78.9         81.0              14.2  ...                  3.0
# 145            76.1         74.6               8.1  ...                  1.2
# 14207          68.4         72.9               7.9  ...                  1.1
# ...             ...          ...               ...  ...                  ...
# 117307         82.9         85.2               5.3  ...                  0.8
# 52933          82.0         84.5              15.0  ...                  0.5
# 91842          82.1         84.1              15.2  ...                  2.1
# 23524          79.4         80.6              11.1  ...                  1.7
# 37757          83.6         86.9              15.1  ...                  1.3
#
#         pct_it_workers_2018  pct_it_workers_2019  pct_it_workers_2020  \
# 31685                   2.0                  2.4                  1.8
# 23384                   0.0                  0.0                  0.0
# 48732                   3.0                  2.7                  2.2
# 145                     1.4                  1.6                  1.7
# 14207                   0.7                  0.5                  0.5
# ...                     ...                  ...                  ...
# 117307                  0.7                  0.7                  0.4
# 52933                   0.7                  0.5                  0.7
# 91842                   2.2                  1.9                  1.6
# 23524                   2.0                  2.1                  3.0
# 37757                   2.7                  1.8                  1.9
#
#         pct_it_workers_2021  median_hh_inc_2017  median_hh_inc_2018  \
# 31685                   1.6               52390             58464.0
# 23384                   0.1               53641             54392.0
# 48732                   2.3               44639             46490.0
# 145                     2.1               43404             45340.0
# 14207                   0.1               39059             40367.0
# ...                     ...                 ...                 ...
# 117307                  0.6               37859             38123.0
# 52933                   0.6               53627             53915.0
# 91842                   1.8               47575             50179.0
# 23524                   2.9               50668             52415.0
# 37757                   1.6               43594             40598.0
#
#         median_hh_inc_2019  median_hh_inc_2020  median_hh_inc_2021
# 31685                63404             67627.0             76755.0
# 23384                63009             66602.0             74792.0
# 48732                47434             47008.0             51117.0
# 145                  47542             51721.0             54277.0
# 14207                41760             46097.0             47020.0
# ...                    ...                 ...                 ...
# 117307               36168             36250.0             38493.0
# 52933                52798             53851.0             57002.0
# 91842                52332             53757.0             57627.0
# 23524                52834             52120.0             53188.0
# 37757                47981             46333.0             50714.0
#
# [24453 rows x 29 columns]

# %%
data['sample_submission']
# Out:
#                  row_id  microbusiness_density
# 0       1001_2022-11-01               3.817671
# 1       1003_2022-11-01               3.817671
# 2       1005_2022-11-01               3.817671
# 3       1007_2022-11-01               3.817671
# 4       1009_2022-11-01               3.817671
# ...                 ...                    ...
# 25075  56037_2023-06-01               3.817671
# 25076  56039_2023-06-01               3.817671
# 25077  56041_2023-06-01               3.817671
# 25078  56043_2023-06-01               3.817671
# 25079  56045_2023-06-01               3.817671
#
# [25080 rows x 2 columns]

# %% [markdown]
# # Boosted Models

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
m = RandomForestRegressor().fit(X_train, y_train)
smape(y_test, m.predict(X_test))
# Out:
# 2.312906866195007

# %% [markdown]
# # Neural Networks

# %%
from sklearn.neural_network import MLPRegressor

# %%
m = MLPRegressor(hidden_layer_sizes=(15, 8, 4, 2)).fit(X_train_scaled, y_train)
smape(y_test, m.predict(X_test_scaled))
# Out:
# 34.92565695430523
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
